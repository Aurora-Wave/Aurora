# %% [markdown]
# # HR gen puro

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test.csv', delimiter=';')

df
# Out:
#    HR_gen_mean_min1  HR_gen_max_min1  HR_gen_mean_min2  HR_gen_max_min2  \
# 0           83.0849       118.577072         81.419655          86.7052
#
#    HR_gen_mean_min3  HR_gen_max_min3  HR_gen_mean_min4  HR_gen_max_min4  \
# 0         83.751999        95.087166         87.925468       102.739723
#
#    HR_gen_mean_min5  HR_gen_max_min5  ...  HR_gen_mean_min8  HR_gen_max_min8  \
# 0         90.726616        100.50251  ...         89.955643       108.892921
#
#    HR_gen_mean_min9  HR_gen_max_min9  HR_gen_mean_min10  HR_gen_max_min10  \
# 0         89.837479       102.739723          91.067146        102.040817
#
#    HR_gen_mean_min11  HR_gen_max_min11  HR_gen_mean_min12  HR_gen_max_min12
# 0          100.63813         113.85199         103.001091        118.343193
#
# [1 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['HR_gen_mean_min1', 'HR_gen_max_min1', 'HR_gen_mean_min2',
#        'HR_gen_max_min2', 'HR_gen_mean_min3', 'HR_gen_max_min3',
#        'HR_gen_mean_min4', 'HR_gen_max_min4', 'HR_gen_mean_min5',
#        'HR_gen_max_min5', 'HR_gen_mean_min6', 'HR_gen_max_min6',
#        'HR_gen_mean_min7', 'HR_gen_max_min7', 'HR_gen_mean_min8',
#        'HR_gen_max_min8', 'HR_gen_mean_min9', 'HR_gen_max_min9',
#        'HR_gen_mean_min10', 'HR_gen_max_min10', 'HR_gen_mean_min11',
#        'HR_gen_max_min11', 'HR_gen_mean_min12', 'HR_gen_max_min12'],
#       dtype='object')

# %%
mean_cols = [col for col in df.columns if 'mean' in col]
max_cols = [col for col in df.columns if 'max' in col]
minutes = range(1, 13)

plt.figure(figsize=(10, 6))
plt.plot(minutes, df[mean_cols].iloc[0], marker='o', label='HR Mean')
plt.plot(minutes, df[max_cols].iloc[0], marker='x', label='HR Max')
plt.xlabel('Minute')
plt.ylabel('Heart Rate')
plt.title('Heart Rate Mean and Max per Minute')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # HR_GEN modificado

# %%
# HR gen puro
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('test2.csv', delimiter=';')

mean_cols = [col for col in df.columns if 'mean' in col]
max_cols = [col for col in df.columns if 'max' in col]
minutes = range(1, 13)

plt.figure(figsize=(10, 6))
plt.plot(minutes, df[mean_cols].iloc[0], marker='o', label='HR Mean')
plt.plot(minutes, df[max_cols].iloc[0], marker='x', label='HR Max')
plt.xlabel('Minute')
plt.ylabel('Heart Rate')
plt.title('Heart Rate Mean and Max per Minute')
plt.legend()
plt.grid(True)
plt.show()
